# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.axes import Axes

# %% [markdown]
# 1. Pregnancies
# 2. Glucose
#      - https://www.emedihealth.com/glands-hormones/diabetes/manage-diabetes
#      -
# 3. BloodPressure
#      - https://www.singlecare.com/blog/blood-pressure-levels/
# 4. SkinThickness
#      - should check the distribution & histogram
# 5. Insulin
#      - should check the distribution & histogram
# 7. BMI
#      - https://theconversation.com/body-mass-index-may-not-be-the-best-indicator-of-our-health-how-can-we-improve-it-143155
# 9. Diabetes Pedigree Function
#      - should check the distribution & histogram
# 1.  Age
#      - https://www.researchgate.net/figure/Subject-Age-Group-Information_fig4_279304799

# %%
def draw_y_lines(boundaries: list, ax: Axes):
    for boundary in boundaries:
        ax.axhline(y=boundary, linestyle='--', color='0.6')


def draw_x_lines(boundaries: list, ax: Axes):
    for boundary in boundaries:
        ax.axvline(x=boundary, linestyle='--', color='0.6')

# %%
data_df=pd.read_csv("data/diabetes.csv")
clean_data_df = data_df[
    (data_df['Glucose'] != 0) &
    (data_df['BloodPressure'] != 0) &
    (data_df['SkinThickness'] != 0) &
    (data_df['Insulin'] != 0) &
    (data_df['BMI'] != 0)
]
clean_data_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   392.000000  392.000000     392.000000     392.000000  392.000000
# mean      3.301020  122.627551      70.663265      29.145408  156.056122
# std       3.211424   30.860781      12.496092      10.516424  118.841690
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.750000
# 50%       2.000000  119.000000      70.000000      29.000000  125.500000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  392.000000                392.000000  392.000000  392.000000
# mean    33.086224                  0.523046   30.864796    0.331633
# std      7.027659                  0.345488   10.200777    0.471401
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.400000                  0.269750   23.000000    0.000000
# 50%     33.200000                  0.449500   27.000000    0.000000
# 75%     37.100000                  0.687000   36.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
pregnancies_boundaries = [-0.5, 0.5, 3.5, 6.5, 9.5, 17.5]
glucose_boundaries = [53, 70, 97.5, 125, 162.5, 200]
blood_pressure_boundaries = [23, 60, 80, 90, 120]
skin_thickness_boundaries = [6, 21, 29, 37, 64]
insulin_boundaries = [13, 76.75, 125.5, 190, 847]
bmi_boundaries = [18, 18.5, 25, 30, 35, 40, 68]
diabetes_pedigree_function_boundaries = [0, 0.27, 0.45, 0.69, 2.24]
age_boundaries = [18, 22, 43, 51, 82]

# %%
fig, ax = plt.subplots(figsize=(10, 10))

draw_x_lines(boundaries=glucose_boundaries, ax=ax)
draw_y_lines(boundaries=age_boundaries, ax=ax)
sns.scatterplot(data=clean_data_df,
                x='Glucose',
                y='Age',
                ax=ax,
                hue='Outcome',
                # palette=hue_colors,
                linewidth=1,
                edgecolor='black',
                alpha=0.7,
                style='Outcome')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

draw_x_lines(boundaries=glucose_boundaries, ax=ax)
draw_y_lines(boundaries=diabetes_pedigree_function_boundaries, ax=ax)
sns.scatterplot(data=clean_data_df,
                x='Glucose',
                y='DiabetesPedigreeFunction',
                ax=ax,
                hue='Outcome',
                # palette=hue_colors,
                linewidth=1,
                edgecolor='black',
                alpha=0.7,
                style='Outcome')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

draw_x_lines(boundaries=glucose_boundaries, ax=ax)
draw_y_lines(boundaries=bmi_boundaries, ax=ax)
sns.scatterplot(data=clean_data_df,
                x='Glucose',
                y='BMI',
                ax=ax,
                hue='Outcome',
                # palette=hue_colors,
                linewidth=1,
                edgecolor='black',
                alpha=0.7,
                style='Outcome')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

draw_x_lines(boundaries=glucose_boundaries, ax=ax)
draw_y_lines(boundaries=insulin_boundaries, ax=ax)
sns.scatterplot(data=clean_data_df,
                x='Glucose',
                y='Insulin',
                ax=ax,
                hue='Outcome',
                # palette=hue_colors,
                linewidth=1,
                edgecolor='black',
                alpha=0.7,
                style='Outcome')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

draw_x_lines(boundaries=glucose_boundaries, ax=ax)
draw_y_lines(boundaries=skin_thickness_boundaries, ax=ax)
sns.scatterplot(data=clean_data_df,
                x='Glucose',
                y='SkinThickness',
                ax=ax,
                hue='Outcome',
                # palette=hue_colors,
                linewidth=1,
                edgecolor='black',
                alpha=0.7,
                style='Outcome')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

draw_x_lines(boundaries=glucose_boundaries, ax=ax)
draw_y_lines(boundaries=blood_pressure_boundaries, ax=ax)
sns.scatterplot(data=clean_data_df,
                x='Glucose',
                y='BloodPressure',
                ax=ax,
                hue='Outcome',
                # palette=hue_colors,
                linewidth=1,
                edgecolor='black',
                alpha=0.7,
                style='Outcome')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

draw_x_lines(boundaries=glucose_boundaries, ax=ax)
draw_y_lines(boundaries=pregnancies_boundaries, ax=ax)
sns.scatterplot(data=clean_data_df,
                x='Glucose',
                y='Pregnancies',
                ax=ax,
                hue='Outcome',
                # palette=hue_colors,
                linewidth=1,
                edgecolor='black',
                alpha=0.7,
                style='Outcome')

plt.show()
